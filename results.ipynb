# %%
import pandas as pd
import numpy as np
from Script.figure import *

# %% [markdown]
# # Figure 3b

# %%
plt.figure(figsize=(32,5))
plt.subplot(161)
results_all_cycle=np.load('./results/ourwork-50-20_alldes_gridsearch_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean1=plot_figure(all_max100,c1='lightblue',c2='blue',title='',ylabel = '')

plt.subplot(162)
results_all_cycle=np.load('./results/ourwork-50-20_alldes_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean2=plot_figure(all_max100,c1='lightgreen',c2='green',title='')

plt.subplot(163)
results_all_cycle=np.load('./results/ourwork-50-20_ohe_automl_total.npy',allow_pickle=True)

all_max100=get_all_max100(results_all_cycle)
recorded_max_mean3=plot_figure(all_max100,c1='yellowgreen',c2='olivedrab',title='')

plt.subplot(164)
results_all_cycle=np.load('./results/ourwork-50-20_mordred_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean4=plot_figure(all_max100,c1='bisque',c2='orange',title='')

plt.subplot(165)
results_all_cycle=np.load('./results/ourwork-50-20_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean5=plot_figure(all_max100,c1='lightcoral',c2='red',title='')

plt.subplot(166)
plt_figure4(recorded_max_mean1,recorded_max_mean2,recorded_max_mean3,recorded_max_mean4,recorded_max_mean5)
# Out:
# 90.6 90.6 69.8 90.9 93.7

# %% [markdown]
# # Figure 3c

# %%
plt.figure(figsize=(22,5))
plt.subplot(141)
results_all_cycle=np.load('./results/Topk_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean1=plot_figure(all_max100,c1='lightblue',c2='blue',title='',ylabel='')

plt.subplot(142)
results_all_cycle=np.load('./results/two_stage_constraint0_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean2=plot_figure(all_max100,c1='lightgreen',c2='green',title='')

plt.subplot(143)
results_all_cycle=np.load('./results/ourwork-50-20_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean3=plot_figure(all_max100,c1='lightcoral',c2='red',title='')

plt.subplot(144)
plt_figure2(recorded_max_mean1,recorded_max_mean2,recorded_max_mean3)
# Out:
# 77.5 90.1 93.7

# %% [markdown]
# # Figure 3d

# %%
plt.figure(figsize=(32,5))
plt.subplot(161)
results_all_cycle=np.load('./results/ourwork-5-2_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean1=plot_figure(all_max100,c1='lightblue',c2='blue',title='',ylabel = '')

plt.subplot(162)
results_all_cycle=np.load('./results/ourwork-10-5_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean2=plot_figure(all_max100,c1='lightgreen',c2='green',title='')

plt.subplot(163)
results_all_cycle=np.load('./results/ourwork-25-10_dft_automl_total.npy',allow_pickle=True)

all_max100=get_all_max100(results_all_cycle)
recorded_max_mean3=plot_figure(all_max100,c1='yellowgreen',c2='olivedrab',title='')

plt.subplot(164)
results_all_cycle=np.load('./results/ourwork-50-20_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean4=plot_figure(all_max100,c1='bisque',c2='orange',title='')

plt.subplot(165)
results_all_cycle=np.load('./results/ourwork-100-40_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean5=plot_figure(all_max100,c1='lightcoral',c2='red',title='')

plt.subplot(166)
plt_figure4(recorded_max_mean1,recorded_max_mean2,recorded_max_mean3,recorded_max_mean4,recorded_max_mean5)
# Out:
# 86.2 92.4 93.6 93.7 93.7

# %% [markdown]
# # Figure 4a

# %%
plt.figure(figsize=(21,5))
plt.subplot(141)
results_all_cycle=np.load('./results/bayesian.npy',allow_pickle=True).reshape(100,-1)[:,:50]
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean1=plot_figure(all_max100,c1='lightblue',c2='blue',title='',ylabel='')

plt.subplot(142)
results_all_cycle=np.load('./results/Topk_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean2=plot_figure(all_max100,c1='yellowgreen',c2='olivedrab',title='')

plt.subplot(143)
results_all_cycle=np.load('./results/ourwork-50-20_dft_automl_total.npy',allow_pickle=True)
all_max100=get_all_max100(results_all_cycle)
recorded_max_mean3=plot_figure(all_max100,c1='lightcoral',c2='red',title='')

plt.subplot(144)
plt_figure2(recorded_max_mean1,recorded_max_mean2,recorded_max_mean3)
# Out:
# 87.1 77.5 93.7
